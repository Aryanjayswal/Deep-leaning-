# %%
import  pandas as pd
import  numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.layers import Dense,Conv2D,Flatten,MaxPooling2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist

# %%
(x_train,y_train),(x_test,y_test)=mnist.load_data()
x_train = x_train.reshape(-1,28,28,1)
x_test = x_test.reshape(-1,28,28,1)
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
modle = Sequential()
modle.add(Conv2D(32,(3,3) ,activation="relu",input_shape=(28,28,1)))
modle.add(MaxPooling2D(2,2))
modle.add(Flatten())
modle.add(Dense(128,activation="relu"))
modle.add(Dense(10,activation="softmax"))
modle.compile(optimizer="adam",loss="categorical_crossentropy",metrics=["accuracy"])
modle.fit(x_train,y_train,epochs=3,validation_data=(x_test,y_test))
los,acc = modle.evaluate(x_test,y_test)
print(acc)

import matplotlib.pyplot as plt
img=x_test[7].reshape(-1,28,28,1)
pre = modle.predict(img)
print(np.argmax(pre))
prediction = np.argmax(pre)
plt.imshow(x_test[7])
# Out:
# Epoch 1/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 47s 24ms/step - accuracy: 0.8703 - loss: 2.3093 - val_accuracy: 0.9675 - val_loss: 0.1157
# Epoch 2/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 41s 22ms/step - accuracy: 0.9753 - loss: 0.0809 - val_accuracy: 0.9737 - val_loss: 0.0874
# Epoch 3/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 40s 21ms/step - accuracy: 0.9827 - loss: 0.0545 - val_accuracy: 0.9756 - val_loss: 0.0956
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9708 - loss: 0.1124
# 0.975600004196167
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 9

# %%
plt.imshow(x_test[7].reshape(28,28))
plt.title(prediction)
plt.show()
